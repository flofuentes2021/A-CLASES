# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
datos = np.genfromtxt('ejemplo-s11c.txt')
x = datos[:,0]
y = datos[:,1]

# %%
#Gráfico de los datos
plt.scatter(x,y)
plt.grid(True)

# %%
#Gráfico de los residuos
plt.scatter(x,res)
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$\\epsilon_i = y_i - f(x_i)$')
# Out:
# Text(0,0.5,'$\\epsilon_i = y_i - f(x_i)$')

# %% [markdown]
# Los residuos muestran una oscilación, que podríamos modelar con la función de tipo: $\alpha \sin{(\beta x + \gamma)}$

# %% [markdown]
# Esto significa que podemos rehacer el ajuste  dde nuestros datos (x,y) usando la siguiente ecuación modificada:
# \begin{equation}
# \bar{f}(x) = a_1 x + a_0 + \alpha \sin{(\beta x + \gamma)}
# \end{equation}

# %%
def f(x,a1,a0,a,b,g):
    return a1*x + a0 + b*np.sin(b*x + g)

# %%
from scipy.optimize import curve_fit

# %%
a1,a0,a,b,g = curve_fit(f,x,y)[0]
print('a1 = ', a1)
print('a0 = ', a0)
print('alpha = ', a)
print('beta = ', b)
print('gamma = ', g)
# Out:
# a1 =  0.999935427546
# a0 =  0.000650170531277
# alpha =  0.00974012181762
# beta =  1.03014446936
# gamma =  -0.0680765089526

# %%
xx = np.linspace(0,10,1000)
plt.plot(xx,f(xx,a1,a0,a,b,g), color= 'red')
plt.scatter(x,y)
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$y$')
# Out:
# Text(0,0.5,'$y$')

# %%
plt.scatter(x,y - f(x,a1,a0,a,b,g))
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$\\epsilon_i = y_i - f(x_i)$')
# Out:
# Text(0,0.5,'$\\epsilon_i = y_i - f(x_i)$')
