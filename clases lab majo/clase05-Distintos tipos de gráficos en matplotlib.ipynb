# %%
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib notebook
#hace que el gráfico en 3d sea manejable

# %%
x = np.linspace(0,10,1000)
y1 = np.sin(x)
y2 = (np.cos(x))**2

# %%
plt.plot(x,y1)

# %%
plt.plot(x,y1)
plt.plot(x,y2)

# %%
plt.subplot(1,2,1)
#numero de filas, numero de columnas y el índice
plt.plot(x,y1)

# %%
plt.figure(figsize=(15,5))
#ancho,largo
plt.subplot(1,2,1)
#el ultimo indice indica que trabaja en el primer gráfico
plt.plot(x,y1)
plt.grid(True)
plt.subplot(1,2,2)
#el último indice indica que trabaja con el segundo grafico
plt.scatter(x,y2)
plt.xlabel('$x$')
# Out:
# Text(0.5,0,'$x$')

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.xticks([0,1,2,3])
#hace las barritas del eje x sólo los números que aparecen en el paréntesis
# Out:
# ([<matplotlib.axis.XTick at 0x7fd28c16c7f0>,
# ...
#  <a list of 4 Text xticklabel objects>)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.xticks(range(11))
#hace 10 lineas en el eje x
# Out:
# ([<matplotlib.axis.XTick at 0x7fd28c0fc160>,
# ...
#  <a list of 11 Text xticklabel objects>)

# %%
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.plot(x,y1)
plt.xticks([4,7], ['$\\alpha$', '$\\gamma$'])
#en el puesto 4 y 7 irán las letvras escritas
# Out:
# ([<matplotlib.axis.XTick at 0x7fd28c10cc18>,
# ...
#  <a list of 2 Text xticklabel objects>)

# %%
plt.plot(x,y1)
plt.grid(True)
plt.xticks([3,7,9],['January','February','March'],rotation=20)
#las etiquetas en los puntos 3,7,9 en x seras esos meses, donde las letras tendrán una rotación de 20°
# Out:
# ([<matplotlib.axis.XTick at 0x7f941a792748>,
# ...
#  <a list of 3 Text xticklabel objects>)

# %%
n = np.array([0,1,2,3,4,5])

# %%
plt.figure(figsize=(10,4))
#Define una figura nueva de 10x4
plt.subplot(1,4,1)
#Arreglo de 1x4 figuras, 1er gráfico
plt.scatter(n, n**2)
#Scatter eran los gráficos sólo de puntos
plt.subplot(1,4,2)
#Arreglo de 1x4 figuras, 2do gráfico
plt.step(n, n**2, lw=2)
#Step es un gráfico de escalón
plt.subplot(1,4,3)
#Arreglo de 1x4 figuras, 3er gráfico
plt.bar(n, n**2, align="center", width=0.5, alpha=0.5)
#Bar son gráficos de barras
plt.subplot(1,4,4)
#Arreglo de 1x4 figuras, 4to gráfico
plt.fill_between(x, x**2, x**3, color="green", alpha=0.5)
#fill between es un gráfico relleno entre ambas funciones x**2  y x***3

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,3,1)
plt.scatter(n, n**2)
plt.subplot(1,3,2)
plt.step(n, n**2, lw=2)
plt.subplot(1,3,3)
plt.bar(n, n**2 )
#(datos eje x, datos eje y o altura,with=0.8 por defecto qque es el ancho, align=center o edge
#que es la alineación de la barra, edge lo alinea a la izquierda, alpha=x controla la transparencia, 
#botton=x las barras comienzan desde x
plt.grid(True)

# %%
# Gráfico polar usando add_axes y proyección polar
plt.figure()
plt.axes([0, 0, 1, 1], polar=True)
t = np.linspace(0, 8*np.pi, 200)
plt.plot(t, t, color='violet', lw=3)
#angulo,radio o puede ser, t,funcion

# %%
plt.errorbar(n,n**2,3, marker='.')
#(x,y,error,marca)
# Out:
# <Container object of 3 artists>

# %%
alpha = 0.7
phi = 2*np.pi*0.5

def flux_qubit_potential(x,y):
    return 2 + alpha - 2 * np.cos(2*np.pi*x)*np.cos(2*np.pi*y) - alpha*np.cos(phi-2*x)
x = np.linspace(0, 1, 100)
y = np.linspace(0, 1, 100)
X,Y = np.meshgrid(x, y)
Z = flux_qubit_potential(X, Y).T

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D
#es para ejecutar figuras en 3d

# %%
ax = plt.subplot(1, 1, 1, projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,  linewidth=0, antialiased=False)
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
plt.bar(n,n**2)
plt.errorbar(n,n**2,2)
# Out:
# <img src="data:image/png;base64,..." width="639.85">
# <Container object of 3 artists>

# %%
plt.barh(n,n**2)
#el grafico queda horizontal
# Out:
# <Container object of 6 artists>
