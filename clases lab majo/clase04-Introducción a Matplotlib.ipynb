# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(1,1)
#(x,y)
#dibuja un punto de tamaño 0 en (1,1)

# %%
plt.plot(1,1, marker='o')
#o= un punto
#*= estrella
#s=cuadrado
#d=diamante

# %%
plt.plot(1,1, marker='o')
plt.plot(2,1, marker='o')

# %%
plt.plot([2,1],[3,4], marker='o')
#coordenadas x, coordenadas y
#une con una linea los puntos ya sea 1 o más puntos

# %%
plt.plot([2,1,3],[3,4,6], marker='o')

# %%
plt.plot([1,2,3],[4,3,6], marker='o')

# %%
data = np.genfromtxt('datos.txt')
x = data[:,0]
y = data[:,1]
print(x)
print(y)
# Out:
# [ 0.1   0.25  0.41  0.56  0.71  0.86  1.02  1.17  1.32  1.47  1.63  1.78
#   1.93  2.08  2.24  2.39  2.54  2.69  2.85  3.  ]
# [ 0.738  0.826  0.981  0.974  0.915  0.897  0.739  0.785  0.635  0.52   0.49
#   0.428  0.497  0.355  0.359  0.328  0.44   0.441  0.433  0.419]

# %%
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.scatter(x,y, marker='*', color='green')
#color de los marcadores
plt.xlabel('$x$ [cm]')
#Agrega medidas en el eje x
# el $ ayuda a poner las letras en modo matemático, funcionando como latex
plt.ylabel('$\\alpha(\\beta)$ [cm]')
#Agrega medidas en el eje y
#para agregar letras u otras cosas de latex aveces hay que usar doble \
plt.title('Gráfico de trayectoria', fontsize=20)
#fontsize es el tamaño del titulo
#Agrega título al gráfico
plt.grid(True)
#Agrega las grillas que ayudan para visualizar
plt.savefig('Grafico de trayectoria.pdf')
#graba la figura

# %%
plt.plot(x,y, marker='*', color='green')
plt.xlabel('$x$ [cm]')
plt.ylabel('$\\alpha(\\beta)$ [cm]')
plt.title('Gráfico de trayectoria2', fontsize=20)
plt.grid(True)
plt.savefig('Grafico de trayectoria2.pdf')

# %% [markdown]
# Ahora usaremos matplotlib para confeccionar un gráfico de la función
# \begin{equation}
# f(x)=\frac{sin(x)}{x}
# \end{equation}
# en el intervalo $x\in[-5,5]$

# %%
x = np.linspace(-5,5,10)
y = np.sin(x)/x
print(x)
print(y)
plt.plot(x,y, marker='o')
# Out:
# [-5.         -3.88888889 -2.77777778 -1.66666667 -0.55555556  0.55555556
#   1.66666667  2.77777778  3.88888889  5.        ]
# [-0.19178485 -0.17476919  0.12810312  0.59724477  0.94934769  0.94934769
#   0.59724477  0.12810312 -0.17476919 -0.19178485]

# %%
#insert cell ab en insert
def f(x):
    return np.sin(x)/x
#definimos una funcion f(x)

# %%
x = np.linspace(-20,20,100)
plt.plot(x,f(x), label='primera función')
plt.plot(x,f(x)/2, label='segunda función')
#los label describen lo que es cada curva con su repectivo color
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$f(x)=\\sin(x)/x$')
plt.legend(loc='best')
plt.savefig('Segundográfico.pdf')
#hace funcionar los label
#loc indica la posición de la simbología de label, en este caso best es la que considera la mejor posicion
#aqupi también se pueden poner numeros que determina en que esquina ponerlo
#dar muchos puntos da la ilución de que la curva es suave
#en MATPLOLOTLIB.STYLES se pueden ver los estilos de gráficos que tiene

# %%
plt.style.available
#muestra los estilos de gráficos disponibles
# Out:
# ['seaborn-poster',
#  'seaborn-deep',
#  'seaborn',
#  'dark_background',
#  'classic',
#  'Solarize_Light2',
#  'seaborn-dark-palette',
#  'fast',
#  'seaborn-paper',
#  'ggplot',
#  'grayscale',
#  '_classic_test',
#  'seaborn-whitegrid',
#  'seaborn-dark',
#  'seaborn-ticks',
#  'seaborn-pastel',
#  'seaborn-notebook',
#  'seaborn-muted',
#  'seaborn-talk',
#  'seaborn-darkgrid',
#  'seaborn-white',
#  'bmh',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'fivethirtyeight']

# %%
plt.style.use('seaborn')
x = np.linspace(-20,20,100)
plt.plot(x,f(x), label='primera función')
plt.plot(x,f(x)/2, label='segunda función')
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$f(x)=\\sin(x)/x$')
plt.legend(loc='best')
plt.savefig('Segundográfico2.pdf')

# %%
plt.style.use('Solarize_Light2')
x = np.linspace(-20,20,100)
plt.plot(x,f(x), label='primera función')
plt.plot(x,f(x)/2, label='segunda función')
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$f(x)=\\sin(x)/x$')
plt.legend(loc='best')
plt.savefig('Segundográficos.pdf')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS', 'StayPuft'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
plt.xkcd()
#estilo como de comic
x = np.linspace(-20,20,100)
plt.plot(x,f(x), label='primera función')
plt.plot(x,f(x)/2, label='segunda función')
plt.grid(True)
plt.xlabel('$x$')
plt.ylabel('$f(x)=\\sin(x)/x$')
plt.legend(loc='best')
plt.savefig('Segundográfico4.pdf')
# Out:
# /usr/lib/python3/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS', 'StayPuft'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
# Out:
# /usr/lib/python3/dist-packages/matplotlib/font_manager.py:1320: UserWarning: findfont: Font family ['xkcd', 'Humor Sans', 'Comic Sans MS', 'StayPuft'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))
