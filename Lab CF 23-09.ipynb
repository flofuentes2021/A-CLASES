# %% [markdown]
# ## LAB FC 23/09

# %% [markdown]
# 1) c)

# %%
import numpy as np
import matplotlib.pyplot as plt


h=0.1
nmax=10000
#n=np.arange(0, 10.0, h)
pi=np.zeros(nmax)
d=np.zeros(nmax)

mu=1
pi[0] =1
d[0] =2

for n in range(nmax-1):
    pi[n+1]= pi[n] + h*pi[n]*(1-d[n]) 
    d[n+1]= d[n] + h*u*d[n]* (pi[n+1]-1)

#plt.plot(pi,d)


C = np.log(d) - d + u*(np.log(pi)-pi)

plt.plot(C)
#plt.ylim(-3,0)
#plt.xlim(0,100)
